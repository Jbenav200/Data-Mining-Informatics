# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# Loading dataset into a dataframe.
data = pd.read_csv('adult.csv')

# %%
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country class-label
# ...

# %%
data.head(20)
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# ...

# %%
data.tail(2)
# Out:
#        age      workclass  fnlwgt education  education-num  \
# 32559   22        Private  201490   HS-grad              9
# 32560   52   Self-emp-inc  287927   HS-grad              9
#
#             marital-status        occupation relationship    race      sex  \
# 32559        Never-married      Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse   Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country class-label
# 32559             0             0              20   United-States       <=50K
# 32560         15024             0              40   United-States        >50K

# %%
data.shape
# Out:
# (32561, 15)

# %% [markdown]
# #### Q1. Use head(2), head(10), tail(2). Explain your observations in no more than 2 to 3 lines

# %%
data.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country class-label
# 0          2174             0              40   United-States       <=50K
# 1             0             0              13   United-States       <=50K

# %%
data.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
data.tail(2)
# Out:
#        age      workclass  fnlwgt education  education-num  \
# 32559   22        Private  201490   HS-grad              9
# 32560   52   Self-emp-inc  287927   HS-grad              9
#
#             marital-status        occupation relationship    race      sex  \
# 32559        Never-married      Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse   Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country class-label
# 32559             0             0              20   United-States       <=50K
# 32560         15024             0              40   United-States        >50K

# %% [markdown]
# When using the head function of the dataframe, and passing a parameter of 2 the first two rows from the top are output. When passing the same function a parameter value of 10, the output is the first ten rows of the dataset. When using the tail function of the dataframe, and passing a parameter value of 2, the last two rows of the dataset are displayed in the output.

# %%
data = data.sample(n=30000, random_state=450)

# %%
data.shape
# Out:
# (30000, 15)

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  30000.000000  3.000000e+04   30000.000000  30000.000000  30000.000000
# mean      38.596800  1.894571e+05      10.082467   1063.867800     87.217367
# std       13.635848  1.050737e+05       2.570905   7299.627718    402.785077
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.177500e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.779985e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.368742e+05      12.000000      0.000000      0.000000
# max       90.000000  1.455435e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    30000.000000
# mean        40.423300
# std         12.351478
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data['education'].value_counts()
# Out:
#  HS-grad         9686
#  Some-college    6723
#  Bachelors       4951
#  Masters         1583
#  Assoc-voc       1261
#  11th            1093
#  Assoc-acdm       982
#  10th             843
#  7th-8th          596
#  Prof-school      528
#  9th              470
#  12th             398
#  Doctorate        380
#  5th-6th          301
#  1st-4th          155
#  Preschool         50
# Name: education, dtype: int64

# %%
data.head()
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 28236   18            Private  301814        HS-grad              9
# 2639    28            Private  128509        5th-6th              3
# 16205   36            Private   99146   Some-college             10
# 2344    44            Private  198282        Masters             14
# 11620   67   Self-emp-not-inc  345236      Bachelors             13
#
#             marital-status          occupation    relationship    race  \
# 28236        Never-married               Sales   Not-in-family   White
# 2639         Never-married   Machine-op-inspct   Not-in-family   White
# 16205   Married-civ-spouse   Machine-op-inspct         Husband   White
# 2344    Married-civ-spouse     Exec-managerial         Husband   White
# 11620   Married-civ-spouse     Exec-managerial         Husband   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# ...

# %%
data = data.drop(['fnlwgt'], axis=1)

# %%
data.shape
# Out:
# (30000, 14)

# %%
data.head()
# Out:
#        age          workclass      education  education-num  \
# 28236   18            Private        HS-grad              9
# 2639    28            Private        5th-6th              3
# 16205   36            Private   Some-college             10
# 2344    44            Private        Masters             14
# 11620   67   Self-emp-not-inc      Bachelors             13
#
#             marital-status          occupation    relationship    race  \
# 28236        Never-married               Sales   Not-in-family   White
# 2639         Never-married   Machine-op-inspct   Not-in-family   White
# 16205   Married-civ-spouse   Machine-op-inspct         Husband   White
# 2344    Married-civ-spouse     Exec-managerial         Husband   White
# 11620   Married-civ-spouse     Exec-managerial         Husband   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 28236   Female             0             0              20   United-States
# ...

# %%
data['age'].groupby([data['sex']]).mean()
# Out:
# sex
#  Female    36.890175
#  Male      39.441692
# Name: age, dtype: float64

# %%
data['age'].groupby([data['sex'], data['education']]).mean()
# Out:
# sex      education
#  Female   10th            35.229927
#           11th            30.439206
#           12th            29.637037
#           1st-4th         49.116279
#           5th-6th         44.090909
#           7th-8th         50.021277
#           9th             42.330769
#           Assoc-acdm      36.403694
#           Assoc-voc       38.229399
#           Bachelors       35.602402
#           Doctorate       45.086420
#           HS-grad         38.694144
#           Masters         42.952772
#           Preschool       40.933333
#           Prof-school     40.209877
#           Some-college    33.924172
#  Male     10th            38.543058
#           11th            33.905797
#           12th            32.562738
#           1st-4th         44.928571
#           5th-6th         42.683036
#           7th-8th         48.197802
#           9th             40.282353
#           Assoc-acdm      37.935323
#           Assoc-voc       39.110837
# ...

# %%
data['capital-gain'].groupby([data['sex'], data['occupation']]).mean()
# Out:
# sex      occupation
#  Female   ?                     302.150454
#           Adm-clerical          532.062794
#           Craft-repair          819.614634
#           Exec-managerial       924.759482
#           Farming-fishing       766.050847
#           Handlers-cleaners     119.298701
#           Machine-op-inspct     187.298387
#           Other-service         165.345531
#           Priv-house-serv       116.676471
#           Prof-specialty       1165.553546
#           Protective-serv      1704.402778
#           Sales                 263.819121
#           Tech-support          658.317901
#           Transport-moving      455.517647
#  Male     ?                     726.081169
#           Adm-clerical          488.594356
#           Armed-Forces            0.000000
#           Craft-repair          660.604004
#           Exec-managerial      2724.392684
#           Farming-fishing       519.576832
#           Handlers-cleaners     270.381638
# ...

# %%
data['capital-gain'].groupby([data['sex'], data['marital-status']]).mean()
# Out:
# sex      marital-status
#  Female   Divorced                  445.054516
#           Married-AF-spouse         189.500000
#           Married-civ-spouse       1421.084912
#           Married-spouse-absent     381.242268
#           Never-married             337.220856
#           Separated                 359.801695
#           Widowed                   458.801325
#  Male     Divorced                 1169.319056
#           Married-AF-spouse         810.888889
#           Married-civ-spouse       1772.102124
#           Married-spouse-absent    1007.090909
#           Never-married             404.258475
#           Separated                 900.275204
#           Widowed                   838.347561
# Name: capital-gain, dtype: float64

# %%
data['age'].groupby(data['race']).max()
# Out:
# race
#  Amer-Indian-Eskimo    82
#  Asian-Pac-Islander    90
#  Black                 90
#  Other                 77
#  White                 90
# Name: age, dtype: int64

# %% [markdown]
# #### Minimum and Maximum age by sex are same?

# %%
data['age'].groupby([data['sex']]).max()
# Out:
# sex
#  Female    90
#  Male      90
# Name: age, dtype: int64

# %%
data['age'].groupby([data['sex']]).min()
# Out:
# sex
#  Female    17
#  Male      17
# Name: age, dtype: int64

# %% [markdown]
# Both sexes in the dataset have the same minimum and maximum age.

# %%
data['age'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column='age')
# Out:
# <AxesSubplot:>

# %%
data['capital-gain'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column='capital-gain')
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column='age', by = 'education', grid=False, rot = 45, fontsize = 10)
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='education'>

# %%
data['education'].value_counts()
# Out:
#  HS-grad         9686
#  Some-college    6723
#  Bachelors       4951
#  Masters         1583
#  Assoc-voc       1261
#  11th            1093
#  Assoc-acdm       982
#  10th             843
#  7th-8th          596
#  Prof-school      528
#  9th              470
#  12th             398
#  Doctorate        380
#  5th-6th          301
#  1st-4th          155
#  Preschool         50
# Name: education, dtype: int64

# %%
data.boxplot(column='capital-gain', by = 'education', grid=False, rot = 45, fontsize = 10)
# Out:
# <AxesSubplot:title={'center':'capital-gain'}, xlabel='education'>

# %%
data['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       13820
#  Never-married             9820
#  Divorced                  4069
#  Separated                  957
#  Widowed                    919
#  Married-spouse-absent      392
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.head()
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 28236   18          4         11              9               4          12
# 2639    28          4          4              3               4           7
# 16205   36          4         15             10               2           7
# 2344    44          4         12             14               2           4
# 11620   67          6          9             13               2           4
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 28236             1     4    0             0             0              20
# 2639              1     4    0             0             0              40
# 16205             0     4    1             0          1887              40
# 2344              0     4    1         15024             0              40
# 11620             0     4    1             0             0              55
#
#        native-country  class-label
# ...

# %%
columns = list(data)
print(columns)
# Out:
# ['age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'class-label']

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# class-label       object
# dtype: object

# %%
c_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'class-label']

# %%
c_columns
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'class-label']

# %%
le = LabelEncoder()
for i in c_columns:
    data[i] = le.fit_transform(data[i])
data.dtypes
# Out:
# age               int64
# workclass         int64
# education         int64
# education-num     int64
# marital-status    int64
# occupation        int64
# relationship      int64
# race              int64
# sex               int64
# capital-gain      int64
# capital-loss      int64
# hours-per-week    int64
# native-country    int64
# class-label       int64
# dtype: object

# %%
data.head()
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 28236   18          4         11              9               4          12
# 2639    28          4          4              3               4           7
# 16205   36          4         15             10               2           7
# 2344    44          4         12             14               2           4
# 11620   67          6          9             13               2           4
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 28236             1     4    0             0             0              20
# 2639              1     4    0             0             0              40
# 16205             0     4    1             0          1887              40
# 2344              0     4    1         15024             0              40
# 11620             0     4    1             0             0              55
#
#        native-country  class-label
# ...

# %% [markdown]
# #### Q6. Write a summary of the outcome of data.describe()

# %%
data.describe()
# Out:
#                 age     workclass     education  education-num  \
# count  30000.000000  30000.000000  30000.000000   30000.000000
# mean      38.596800      3.866733     10.303600      10.082467
# std       13.635848      1.454594      3.865358       2.570905
# min       17.000000      0.000000      0.000000       1.000000
# 25%       28.000000      4.000000      9.000000       9.000000
# 50%       37.000000      4.000000     11.000000      10.000000
# 75%       48.000000      4.000000     12.000000      12.000000
# max       90.000000      8.000000     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean         2.613933      6.569700      1.446000      3.665167      0.668867
# std          1.505355      4.230627      1.607577      0.849320      0.470629
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# ...

# %% [markdown]
# data.describe() is a method provided by the pandas library which allows us to review some standard calculations performed on our data. For example, I can see that the mean (average) age in my specific data set is 38.5. I can see that the 25th percentile of workclass within my data has a value of 4, before the values were encoded/transformed, this was 'Private'.

# %% [markdown]
# #### Q7. What are the different data types (or attribute types) in data mining? Explain with the help of the examples from the Adult dataset.

# %% [markdown]
# The two data types I've seen so far for data mining are int64 (a 64bit integer) and Object. An Integer is a numeric value, for example in our Adult dataset, age is a number and so would naturally be type int64. Sex however is a string value, though when you run data.dtypes (before the data transformation) you would see Object. You also have float64 which is a 64bit number with a decimal point.

# %% [markdown]
# #### Q8. Highest migrants belongs to which country?

# %%
data['native-country'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data['native-country'].value_counts()
# Out:
# 39    26884
# 26      588
# 0       544
# 30      188
# 11      126
# 2       108
# 33      101
# 8        97
# 19       91
# 9        85
# 5        84
# 23       74
# 35       71
# 22       68
# 6        66
# 3        64
# 40       61
# 13       58
# 31       56
# 24       54
# 4        54
# 36       50
# 14       43
# 20       43
# 32       34
# 12       27
# 10       26
# 27       26
# 29       26
# 7        26
# 21       24
# 17       19
# 38       17
# 25       17
# 1        17
# 37       17
# 41       16
# 18       13
# 16       13
# 28       12
# 34       11
# 15        1
# Name: native-country, dtype: int64

# %% [markdown]
# Country 39, is the country which most migrants belong to. This can be seen by using the data['native-country'].value_counts() function from pandas or by using the matplotlib histogram chart. The chart gives us a visual representation of our data, and value_counts gives us a numerical breakdown of how many people in our dataset belong to which value. In the example above 26884 people are from the United States.

# %% [markdown]
# #### Q9. Which occupation represents more males than females?

# %%
data['occupation'].groupby([data['sex']]).value_counts()
# Out:
# sex      occupation
#  Female   Adm-clerical         2341
#           Other-service        1667
#           Prof-specialty       1382
#           Sales                1161
#           Exec-managerial      1081
#           ?                     771
#           Machine-op-inspct     496
#           Tech-support          324
#           Craft-repair          205
#           Handlers-cleaners     154
#           Priv-house-serv       136
#           Transport-moving       85
#           Protective-serv        72
#           Farming-fishing        59
#  Male     Craft-repair         3596
#           Exec-managerial      2679
#           Prof-specialty       2433
#           Sales                2193
#           Transport-moving     1383
#           Other-service        1358
#           Machine-op-inspct    1321
#           Adm-clerical         1134
#           Handlers-cleaners    1111
#           ?                     924
#           Farming-fishing       846
# ...

# %% [markdown]
# The occupation which represents more males than females is occupation Craft-repair.

# %%
data['native-country'].value_counts()
# Out:
#  United-States                 26884
#  Mexico                          588
#  ?                               544
#  Philippines                     188
#  Germany                         126
#  Canada                          108
#  Puerto-Rico                     101
#  El-Salvador                      97
#  India                            91
#  England                          85
#  Cuba                             84
#  Jamaica                          74
#  South                            71
#  Italy                            68
#  Dominican-Republic               66
#  China                            64
#  Vietnam                          61
#  Guatemala                        58
#  Poland                           56
#  Japan                            54
#  Columbia                         54
#  Taiwan                           50
#  Haiti                            43
#  Iran                             43
#  Portugal                         34
# ...

# %%
data['occupation'].groupby([data['sex']]).value_counts()
# Out:
# sex      occupation
#  Female   Adm-clerical         2341
#           Other-service        1667
#           Prof-specialty       1382
#           Sales                1161
#           Exec-managerial      1081
#           ?                     771
#           Machine-op-inspct     496
#           Tech-support          324
#           Craft-repair          205
#           Handlers-cleaners     154
#           Priv-house-serv       136
#           Transport-moving       85
#           Protective-serv        72
#           Farming-fishing        59
#  Male     Craft-repair         3596
#           Exec-managerial      2679
#           Prof-specialty       2433
#           Sales                2193
#           Transport-moving     1383
#           Other-service        1358
#           Machine-op-inspct    1321
#           Adm-clerical         1134
#           Handlers-cleaners    1111
#           ?                     924
#           Farming-fishing       846
# ...
